# %%
Given two strings s and t which consist of only lowercase letters.

String t is generated by random shuffling string s and then add one more letter at a random position.

Find the letter that was added in t.

Example:

Input:
s = "abcd"
t = "abcde"

Output:
e

Explanation:
'e' is the letter that was added.

# %%
法一：空間換時間，建立大小為26的list儲存每一個字母的數量，多的就是答案

# %%
class Solution:
    def findTheDifference(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: str
        """
        sc = [0]*26
        tc = [0]*26
        #ord('a')=97
        for i in range(len(s)):
            sc[ord(s[i])-97]+=1
        for i in range(len(t)):
            tc[ord(t[i])-97]+=1
        for i in range(26):
            if sc[i]!=tc[i]:
                return chr(i+97)

# %%
法二：使用collection.Counter()

# %%
class Solution(object):
    def findTheDifference(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: str
        """
        import collections
        ds = collections.Counter(s)
        dt = collections.Counter(t)
        return list((dt - ds).keys())[-1]

# %%
s = "abcd"
t = "abcde"

a = Solution()
a.findTheDifference(s,t)
# Out:
# 'e'

# %% [markdown]
# # 注意

# %%
ord(char) #把char轉為ascii數字，a為97
chr(ascii) #把ascii轉為char

# %%
collections.Counter(s)  #功能跟R的table()很像，會製造出collection物件，裡面是每個元素的次數
#兩個collection物件可以直接相減找出差異!!!!
